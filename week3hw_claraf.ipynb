# %% [markdown]
# ## Week 3 Assignment
# **Author**: Clara Fuchshuber
#
# **Description**: Looking at age and housing units by age of householder in Chinatown, Lincoln Heights, Echo Park, and Elysian Park by block group

# %%
# import libraries
import pandas

# %%
age = pandas.read_csv('Censusagedata.csv')

# %%
# taking a look at the data
age.shape
# Out:
# (2498, 88)

# %%
age.sample(5)
# Out:
#         Geo_FIPS                                          Geo_QName  \
# 2001  6037574201  Census Tract 5742.01, Los Angeles County, Cali...
# 1940  6037570202  Census Tract 5702.02, Los Angeles County, Cali...
# 2435  6037920118  Census Tract 9201.18, Los Angeles County, Cali...
# 2182  6037650001  Census Tract 6500.01, Los Angeles County, Cali...
# 779   6037227020  Census Tract 2270.20, Los Angeles County, Cali...
#
#      Geo_FILEID Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO  Geo_US  \
# 2001      ACSSF         ca         140            0          6201     NaN
# 1940      ACSSF         ca         140            0          6140     NaN
# 2435      ACSSF         ca         140            0          6635     NaN
# 2182      ACSSF         ca         140            0          6382     NaN
# 779       ACSSF         ca         140            0          4979     NaN
#
#       Geo_REGION  Geo_DIVISION  ...  SE_A01003B_001  SE_A01003B_002  \
# ...

# %%
age.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2498 entries, 0 to 2497
# Data columns (total 88 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Geo_FIPS        2498 non-null   int64
#  1   Geo_QName       2498 non-null   object
#  2   Geo_FILEID      2498 non-null   object
#  3   Geo_STUSAB      2498 non-null   object
#  4   Geo_SUMLEV      2498 non-null   int64
#  5   Geo_GEOCOMP     2498 non-null   int64
#  6   Geo_LOGRECNO    2498 non-null   int64
#  7   Geo_US          0 non-null      float64
#  8   Geo_REGION      0 non-null      float64
#  9   Geo_DIVISION    0 non-null      float64
#  10  Geo_STATECE     0 non-null      float64
#  11  Geo_STATE       2498 non-null   int64
#  12  Geo_COUNTY      2498 non-null   int64
#  13  Geo_COUSUB      0 non-null      float64
#  14  Geo_PLACE       0 non-null      float64
#  15  Geo_TRACT       2498 non-null   int64
#  16  Geo_BLKGRP      0 non-null      float64
# ...

# %%
# forgot to import FIPS columns as a string 
age = pandas.read_csv(
    'Censusagedata.csv',
    dtype = 
    {
        'Geo_FIPS':str,
        'Geo_STATE':str,
        'Geo_COUNTY':str
    }
)
age.sample(5)
# Out:
#          Geo_FIPS                                          Geo_QName  \
# 1172  06037320101  Census Tract 3201.01, Los Angeles County, Cali...
# 1158  06037310705  Census Tract 3107.05, Los Angeles County, Cali...
# 1852  06037551001  Census Tract 5510.01, Los Angeles County, Cali...
# 1056  06037293205  Census Tract 2932.05, Los Angeles County, Cali...
# 2231  06037670418  Census Tract 6704.18, Los Angeles County, Cali...
#
#      Geo_FILEID Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO  Geo_US  \
# 1172      ACSSF         ca         140            0          5372     NaN
# 1158      ACSSF         ca         140            0          5358     NaN
# 1852      ACSSF         ca         140            0          6052     NaN
# 1056      ACSSF         ca         140            0          5256     NaN
# 2231      ACSSF         ca         140            0          6431     NaN
#
#       Geo_REGION  Geo_DIVISION  ...  SE_A01003B_001 SE_A01003B_002  \
# ...

# %%
age.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2498 entries, 0 to 2497
# Data columns (total 88 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Geo_FIPS        2498 non-null   object
#  1   Geo_QName       2498 non-null   object
#  2   Geo_FILEID      2498 non-null   object
#  3   Geo_STUSAB      2498 non-null   object
#  4   Geo_SUMLEV      2498 non-null   int64
#  5   Geo_GEOCOMP     2498 non-null   int64
#  6   Geo_LOGRECNO    2498 non-null   int64
#  7   Geo_US          0 non-null      float64
#  8   Geo_REGION      0 non-null      float64
#  9   Geo_DIVISION    0 non-null      float64
#  10  Geo_STATECE     0 non-null      float64
#  11  Geo_STATE       2498 non-null   object
#  12  Geo_COUNTY      2498 non-null   object
#  13  Geo_COUSUB      0 non-null      float64
#  14  Geo_PLACE       0 non-null      float64
#  15  Geo_TRACT       2498 non-null   int64
#  16  Geo_BLKGRP      0 non-null      float64
# ...

# %%
# deleting empty columns
age.columns[age.isna().all()].tolist()
# Out:
# ['Geo_US',
#  'Geo_REGION',
#  'Geo_DIVISION',
#  'Geo_STATECE',
#  'Geo_COUSUB',
#  'Geo_PLACE',
#  'Geo_BLKGRP',
#  'Geo_CONCIT',
#  'Geo_AIANHH',
#  'Geo_AIANHHFP',
#  'Geo_AIHHTLI',
#  'Geo_AITSCE',
#  'Geo_AITS',
#  'Geo_ANRC',
#  'Geo_CBSA',
#  'Geo_CSA',
#  'Geo_METDIV',
#  'Geo_MACC',
#  'Geo_MEMI',
#  'Geo_NECTA',
#  'Geo_CNECTA',
#  'Geo_NECTADIV',
#  'Geo_UA',
#  'Geo_UACP',
#  'Geo_CDCURR',
#  'Geo_SLDU',
#  'Geo_SLDL',
#  'Geo_VTD',
#  'Geo_ZCTA3',
#  'Geo_ZCTA5',
#  'Geo_SUBMCD',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_UR',
#  'Geo_PCI',
#  'Geo_TAZ',
#  'Geo_UGA',
#  'Geo_PUMA5',
#  'Geo_PUMA1',
#  'Geo_BTTR',
#  'Geo_BTBG',
#  'Geo_PLACESE']

# %%
# creating new dataframe that does not include empty rows
age1 = age.dropna(axis=1,how='all')

# %%
age1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2498 entries, 0 to 2497
# Data columns (total 45 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Geo_FIPS        2498 non-null   object
#  1   Geo_QName       2498 non-null   object
#  2   Geo_FILEID      2498 non-null   object
#  3   Geo_STUSAB      2498 non-null   object
#  4   Geo_SUMLEV      2498 non-null   int64
#  5   Geo_GEOCOMP     2498 non-null   int64
#  6   Geo_LOGRECNO    2498 non-null   int64
#  7   Geo_STATE       2498 non-null   object
#  8   Geo_COUNTY      2498 non-null   object
#  9   Geo_TRACT       2498 non-null   int64
#  10  Geo_GEOID       2498 non-null   object
#  11  Geo_NAME        2498 non-null   object
#  12  SE_A01001_001   2498 non-null   int64
#  13  SE_A01001_002   2498 non-null   int64
#  14  SE_A01001_003   2498 non-null   int64
#  15  SE_A01001_004   2498 non-null   int64
#  16  SE_A01001_005   2498 non-null   int64
# ...

# %%
age1.head()
# Out:
#       Geo_FIPS                                          Geo_QName Geo_FILEID  \
# 0  06037101110  Census Tract 1011.10, Los Angeles County, Cali...      ACSSF
# 1  06037101122  Census Tract 1011.22, Los Angeles County, Cali...      ACSSF
# 2  06037101220  Census Tract 1012.20, Los Angeles County, Cali...      ACSSF
# 3  06037101221  Census Tract 1012.21, Los Angeles County, Cali...      ACSSF
# 4  06037101222  Census Tract 1012.22, Los Angeles County, Cali...      ACSSF
#
#   Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO Geo_STATE Geo_COUNTY  \
# 0         ca         140            0          4200        06        037
# 1         ca         140            0          4201        06        037
# 2         ca         140            0          4202        06        037
# 3         ca         140            0          4203        06        037
# 4         ca         140            0          4204        06        037
#
# ...

# %%
pandas.set_option('display.max_columns', None)
pandas.set_option('display.max_rows', None)
age1.head()
# Out:
#       Geo_FIPS                                          Geo_QName Geo_FILEID  \
# 0  06037101110  Census Tract 1011.10, Los Angeles County, Cali...      ACSSF
# 1  06037101122  Census Tract 1011.22, Los Angeles County, Cali...      ACSSF
# 2  06037101220  Census Tract 1012.20, Los Angeles County, Cali...      ACSSF
# 3  06037101221  Census Tract 1012.21, Los Angeles County, Cali...      ACSSF
# 4  06037101222  Census Tract 1012.22, Los Angeles County, Cali...      ACSSF
#
#   Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO Geo_STATE Geo_COUNTY  \
# 0         ca         140            0          4200        06        037
# 1         ca         140            0          4201        06        037
# 2         ca         140            0          4202        06        037
# 3         ca         140            0          4203        06        037
# 4         ca         140            0          4204        06        037
#
# ...

# %%
# Created new dataframe for age
columns_to_keep = ['Geo_FIPS', 
                   'SE_A01001_001', 
                   'SE_A01001_002', 
                   'SE_A01001_003',
                   'SE_A01001_004',
                   'SE_A01001_005',
                   'SE_A01001_006',
                   'SE_A01001_007',
                   'SE_A01001_008',
                   'SE_A01001_009',
                   'SE_A01001_010',
                   'SE_A01001_011',
                   'SE_A01001_012',
                   'SE_A01001_013']
age2 = age1[columns_to_keep]

# %%
age2.head()
# Out:
#       Geo_FIPS  SE_A01001_001  SE_A01001_002  SE_A01001_003  SE_A01001_004  \
# 0  06037101110           3879            131             96            178
# 1  06037101122           4247            131            217            247
# 2  06037101220           3583            132            196            245
# 3  06037101221           3723            134            146            207
# 4  06037101222           2690             56            276            166
#
#    SE_A01001_005  SE_A01001_006  SE_A01001_007  SE_A01001_008  SE_A01001_009  \
# 0            172            235            557            554            586
# 1             91            415            313            421            776
# 2             72            294            512            437            621
# 3            158            448            425            659            407
# 4             19            184            404            397            495
#
# ...

# %%
age1.head()
# Out:
#       Geo_FIPS                                          Geo_QName Geo_FILEID  \
# 0  06037101110  Census Tract 1011.10, Los Angeles County, Cali...      ACSSF
# 1  06037101122  Census Tract 1011.22, Los Angeles County, Cali...      ACSSF
# 2  06037101220  Census Tract 1012.20, Los Angeles County, Cali...      ACSSF
# 3  06037101221  Census Tract 1012.21, Los Angeles County, Cali...      ACSSF
# 4  06037101222  Census Tract 1012.22, Los Angeles County, Cali...      ACSSF
#
#   Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO Geo_STATE Geo_COUNTY  \
# 0         ca         140            0          4200        06        037
# 1         ca         140            0          4201        06        037
# 2         ca         140            0          4202        06        037
# 3         ca         140            0          4203        06        037
# 4         ca         140            0          4204        06        037
#
# ...

# %%
# created new dataframe for age of householder
columns_to_keep2 = ['Geo_FIPS',
                    'SE_A10020_001',
                    'SE_A10020_002',
                    'SE_A10020_003',
                    'SE_A10020_004',
                    'SE_A10020_005',
                    'SE_A10020_006',
                    'SE_A10020_007',
                    'SE_A10020_008',
                    'SE_A10020_009',
                    'SE_A10020_010']
age_household = age1[columns_to_keep2]

# %%
age_household.head()
# Out:
#       Geo_FIPS  SE_A10020_001  SE_A10020_002  SE_A10020_003  SE_A10020_004  \
# 0  06037101110           1494             38            108            251
# 1  06037101122           1372             33            157            155
# 2  06037101220           1357              5            124            220
# 3  06037101221           1450             11            193            373
# 4  06037101222            935              0            162            155
#
#    SE_A10020_005  SE_A10020_006  SE_A10020_007  SE_A10020_008  SE_A10020_009  \
# 0            401            128            150            324             78
# 1            250            197            221            206            136
# 2            358            193            136            199            113
# 3            257             62            194            237              0
# 4            195             76            114            153             80
#
#    SE_A10020_010
# 0             16
# ...

# %%
age1.head()
# Out:
#       Geo_FIPS                                          Geo_QName Geo_FILEID  \
# 0  06037101110  Census Tract 1011.10, Los Angeles County, Cali...      ACSSF
# 1  06037101122  Census Tract 1011.22, Los Angeles County, Cali...      ACSSF
# 2  06037101220  Census Tract 1012.20, Los Angeles County, Cali...      ACSSF
# 3  06037101221  Census Tract 1012.21, Los Angeles County, Cali...      ACSSF
# 4  06037101222  Census Tract 1012.22, Los Angeles County, Cali...      ACSSF
#
#   Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO Geo_STATE Geo_COUNTY  \
# 0         ca         140            0          4200        06        037
# 1         ca         140            0          4201        06        037
# 2         ca         140            0          4202        06        037
# 3         ca         140            0          4203        06        037
# 4         ca         140            0          4204        06        037
#
# ...

# %%
# created new dataframe for age of renter
columns_to_keep3 = ['Geo_FIPS',
                    'SE_A01003B_001',
                    'SE_A01003B_002',
                    'SE_A01003B_003',
                    'SE_A01003B_004',
                    'SE_A01003B_005',
                    'SE_A01003B_006',
                    'SE_A01003B_007',
                    'SE_A01003B_008',
                    'SE_A01003B_009',
                    'SE_A01003B_010']
age_renter = age1[columns_to_keep3].copy()

# %%
age_renter.head()
# Out:
#       Geo_FIPS  SE_A01003B_001  SE_A01003B_002  SE_A01003B_003  \
# 0  06037101110             644              38              73
# 1  06037101122             344              33             113
# 2  06037101220             762               5              81
# 3  06037101221            1140               0             125
# 4  06037101222             816               0             155
#
#    SE_A01003B_004  SE_A01003B_005  SE_A01003B_006  SE_A01003B_007  \
# 0              93             124              94              49
# 1              41              99              58               0
# 2             169             175              80              92
# 3             335             208              62             167
# 4             155             152              76              45
#
#    SE_A01003B_008  SE_A01003B_009  SE_A01003B_010
# 0             123              42               8
# 1               0               0               0
# ...

# %%
# Renaming the columns in my 3 new dataframes
age2.columns = ['FIPS',
                'TotalPop',
                'Under 5 Years',
                '5 to 9 Years',
                '10 to 14 Years',
                '15 to 17 Years',
                '18 to 24 Years',
                '25 to 34 Years',
                '35 to 44 Years',
                '45 to 54 Years',
                '55 to 64 Years',
                '65 to 74 Years',
                '75 to 84 Years',
                '85 Years and Over']
age2.sample(5)
# Out:
#              FIPS  TotalPop  Under 5 Years  5 to 9 Years  10 to 14 Years  \
# 2201  06037650901      5028            323           270             185
# 934   06037265100      2395             32            80             155
# 1626  06037503502      4338            270           305             379
# 2177  06037621204      2742             92            26              43
# 2443  06037920314      3448            233           257             319
#
#       15 to 17 Years  18 to 24 Years  25 to 34 Years  35 to 44 Years  \
# 2201             181             258             692             511
# 934               70              77             106              83
# 1626             292             309             602             719
# 2177              88              64             545             333
# 2443             108             369             426             323
#
#       45 to 54 Years  55 to 64 Years  65 to 74 Years  75 to 84 Years  \
# ...

# %%
age_household.columns = ['FIPS',
                         'Occupied Housing Units',
                         'Householder 15 to 24 Years',
                         'Householder 25 to 34 Years',
                         'Householder 35 to 44 Years',
                         'Householder 45 to 54 Years',
                         'Householder 55 to 59 Years',
                         'Householder 60 to 64 Years',
                         'Householder 65 to 74 Years',
                         'Householder 75 to 84 Years',
                         'Householder 85 Years and Over']
age_household.sample(5)
# Out:
#              FIPS  Occupied Housing Units  Householder 15 to 24 Years  \
# 2138  06037603703                     845                           0
# 1991  06037573300                    1072                          35
# 1130  06037301901                    1826                          46
# 269   06037131022                    1011                         100
# 2163  06037620601                    2233                           8
#
#       Householder 25 to 34 Years  Householder 35 to 44 Years  \
# 2138                          81                         172
# 1991                         137                         319
# 1130                         266                         364
# 269                          215                         242
# 2163                         363                         587
#
#       Householder 45 to 54 Years  Householder 55 to 59 Years  \
# 2138                         186                         131
# ...

# %%
age_renter.columns = ['FIPS',
                      'Renter-Occupied Housing Units',
                      'Renter 15 to 24 Years',
                      'Renter 25 to 34 Years',
                      'Renter 35 to 44 Years',
                      'Renter 45 to 54 Years',
                      'Renter 55 to 59 Years',
                      'Renter 60 to 64 Years',
                      'Renter 65 to 74 Years',
                      'Renter 75 to 84 Years',
                      'Renter 85 Years and Over']
age_renter.sample(5)
# Out:
#              FIPS  Renter-Occupied Housing Units  Renter 15 to 24 Years  \
# 1198  06037401303                            139                      0
# 137   06037117408                            615                     13
# 810   06037231800                           1226                      0
# 2317  06037900606                           1073                     39
# 545   06037201301                            531                      0
#
#       Renter 25 to 34 Years  Renter 35 to 44 Years  Renter 45 to 54 Years  \
# 1198                      0                     26                     14
# 137                     189                    158                    122
# 810                     236                    365                    369
# 2317                    457                    111                    232
# 545                     128                    112                     32
#
#       Renter 55 to 59 Years  Renter 60 to 64 Years  Renter 65 to 74 Years  \
# ...

# %%
age2['TotalPop'].median()
# Out:
# 3933.0

# %%
age2.sample(5)
# Out:
#         Geo_FIPS  SE_A01001_001  SE_A01001_002  SE_A01001_003  SE_A01001_004  \
# 331  06037137000           5098            209            337            258
# 845  06037236205           2846            133            316            292
# 253  06037128101           2995            132            123            212
# 659  06037211922           3674            299            115            116
# 392  06037181300           3867            234            172            169
#
#      SE_A01001_005  SE_A01001_006  SE_A01001_007  SE_A01001_008  \
# 331            152            377            431            538
# 845             83            285            490            371
# 253             95            294            515            381
# 659            104            471            735            632
# 392             80            209            657            597
#
#      SE_A01001_009  SE_A01001_010  SE_A01001_011  SE_A01001_012  SE_A01001_013
# ...

# %%
# Creating bargraphns for my 3 new dataframes. Looking at age, age of householder, age of renter
sum_under_5 = age2['Under 5 Years'].sum()
sum_5_to_9 = age2['5 to 9 Years'].sum()
sum_10_to_14 = age2['10 to 14 Years'].sum()
sum_15_to_17 = age2['15 to 17 Years'].sum()
sum_18_to_24 = age2['18 to 24 Years'].sum()
sum_25_to_34 = age2['25 to 34 Years'].sum()
sum_35_to_44 = age2['35 to 44 Years'].sum()
sum_45_to_54 = age2['45 to 54 Years'].sum()
sum_55_to_65 = age2['55 to 64 Years'].sum()
sum_65_to_74 = age2['65 to 74 Years'].sum()
sum_75_to_84 = age2['75 to 84 Years'].sum()
sum_85_over = age2['85 Years and Over'].sum() 
age2.dtypes
# Out:
# FIPS                 object
# TotalPop              int64
# Under 5 Years         int64
# 5 to 9 Years          int64
# 10 to 14 Years        int64
# 15 to 17 Years        int64
# 18 to 24 Years        int64
# 25 to 34 Years        int64
# 35 to 44 Years        int64
# 45 to 54 Years        int64
# 55 to 64 Years        int64
# 65 to 74 Years        int64
# 75 to 84 Years        int64
# 85 Years and Over     int64
# dtype: object

# %%
df = pandas.DataFrame({'Age in Years':['Under 5','5 to 9','10 to 14','15 to 17','18 to 24','25 to 34','35 to 44','45 to 55','55 to 64','65 to 74','75 to 84','85 and Over'], 
                       'Population':[sum_under_5,sum_5_to_9,sum_10_to_14,sum_15_to_17,sum_18_to_24,sum_25_to_34,sum_35_to_44,sum_45_to_54,sum_55_to_65,sum_65_to_74,sum_75_to_84,sum_85_over]})
df.plot.bar(x='Age in Years', y='Population', ylabel='Population',rot=90)
# Out:
# <AxesSubplot: xlabel='Age in Years', ylabel='Population'>

# %%
age_household.sample(5)
# Out:
#              FIPS  Occupied Housing Units  Householder 15 to 24 Years  \
# 38    06037104822                     645                          19
# 2443  06037920314                    1030                          28
# 2459  06037980001                       0                           0
# 1434  06037433302                     457                          22
# 1455  06037460101                    2341                           0
#
#       Householder 25 to 34 Years  Householder 35 to 44 Years  \
# 38                            58                         141
# 2443                         122                         195
# 2459                           0                           0
# 1434                         107                          71
# 1455                         158                         242
#
#       Householder 45 to 54 Years  Householder 55 to 59 Years  \
# 38                           129                          37
# ...

# %%
sum_house_15_24 = age_household['Householder 15 to 24 Years'].sum()
sum_house_25_34 = age_household['Householder 25 to 34 Years'].sum()
sum_house_35_44 = age_household['Householder 35 to 44 Years'].sum()
sum_house_45_54 = age_household['Householder 45 to 54 Years'].sum()
sum_house_55_59 = age_household['Householder 55 to 59 Years'].sum()
sum_house_60_64 = age_household['Householder 60 to 64 Years'].sum()
sum_house_65_74 = age_household['Householder 65 to 74 Years'].sum()
sum_house_75_84 = age_household['Householder 75 to 84 Years'].sum()
sum_house_85_older = age_household['Householder 85 Years and Over'].sum()

df1 = pandas.DataFrame({'Householder Age':['15 to 24','25 to 34','35 to 44','45 to 54','55 to 59','60 to 64','65 to 74','75 to 84','85 and Over'], 
                       'Population':[sum_house_15_24,sum_house_25_34,sum_house_35_44,sum_house_45_54,sum_house_55_59,sum_house_60_64,sum_house_65_74,sum_house_75_84,sum_house_85_older]})
df1.plot.bar(x='Householder Age', y='Population', ylabel='Population',rot=90)
# Out:
# <AxesSubplot: xlabel='Householder Age', ylabel='Population'>

# %%
age_renter.sample(5)
# Out:
#              FIPS  Renter-Occupied Housing Units  Renter 15 to 24 Years  \
# 647   06037211320                           1237                     36
# 2421  06037920047                           1827                    232
# 137   06037117408                            615                     13
# 396   06037183101                            484                      0
# 366   06037141303                           1393                     18
#
#       Renter 25 to 34 Years  Renter 35 to 44 Years  Renter 45 to 54 Years  \
# 647                     328                    171                    280
# 2421                    535                    562                    283
# 137                     189                    158                    122
# 396                     163                    108                    105
# 366                     494                    309                    218
#
#       Renter 55 to 59 Years  Renter 60 to 64 Years  Renter 65 to 74 Years  \
# ...

# %%
sum_rent_15_24 = age_renter['Renter 15 to 24 Years'].sum()
sum_rent_25_34 = age_renter['Renter 25 to 34 Years'].sum()
sum_rent_35_44 = age_renter['Renter 35 to 44 Years'].sum()
sum_rent_45_54 = age_renter['Renter 45 to 54 Years'].sum()
sum_rent_55_59 = age_renter['Renter 55 to 59 Years'].sum()
sum_rent_60_64 = age_renter['Renter 60 to 64 Years'].sum()
sum_rent_65_74 = age_renter['Renter 65 to 74 Years'].sum()
sum_rent_75_84 = age_renter['Renter 75 to 84 Years'].sum()
sum_rent_85_older = age_renter['Renter 85 Years and Over'].sum()

df2 = pandas.DataFrame({'Renter Age':['15 to 24','25 to 34','35 to 44','45 to 54','55 to 59','60 to 64','65 to 74','75 to 84','85 and Over'], 
                       'Population':[sum_rent_15_24,sum_rent_25_34,sum_rent_35_44,sum_rent_45_54,sum_rent_55_59,sum_rent_60_64,sum_rent_65_74,sum_rent_75_84,sum_rent_85_older]})
df2.plot.bar(x='Renter Age', y='Population', ylabel='Population',rot=90)
# Out:
# <AxesSubplot: xlabel='Renter Age', ylabel='Population'>

# %%
# going to try graphing the renter age data specifically for the Chinatown area
import geopandas

# %%
blockgroups = geopandas.read_file('blockgroups_chinatown.zip')

# %%
blockgroups.sample(5)
# Out:
#     OBJECTID     BG20    CT20 LABEL    ShapeSTAre    ShapeSTLen      Geo_FIPS  \
# 0       1047  1873001  187300  BG 1  7.624962e+06  19990.718397  060371873001
# 31      1281  1977001  197700  BG 1  2.939201e+06   8174.158814  060371977001
# 27      1277  1975002  197500  BG 2  1.487711e+06   5485.869133  060371975002
# 30      1280  1976002  197600  BG 2  2.359107e+06   6604.048933  060371976002
# 5       1245  1956001  195600  BG 1  1.398968e+06   5034.642628  060371956001
#
#    Geo_STATE Geo_COUNTY  Renter-Occ  Renter-O_1  Renter-O_2  Renter-O_3  \
# 0         06        037         446           0           7           0
# 31        06        037         782           0          36          32
# 27        06        037         311           0          36           0
# 30        06        037         396           5           5           4
# 5         06        037         135           0           0           0
#
# ...

# %%
desired_columns = ['OBJECTID','BG20','CT20','LABEL','ShapeSTAre','ShapeSTLen','Geo_FIPS','Geo_STATE','Geo_COUNTY','geometry']
chinatown = blockgroups[desired_columns].copy()

# %%
chinatown.sample(5)
# Out:
#     OBJECTID     BG20    CT20 LABEL    ShapeSTAre    ShapeSTLen      Geo_FIPS  \
# 32      1282  1977002  197700  BG 2  1.535249e+06   6076.894874  060371977002
# 58      1322  2014021  201402  BG 1  1.302289e+07  17504.720316  060372014021
# 27      1277  1975002  197500  BG 2  1.487711e+06   5485.869133  060371975002
# 34      1284  1990011  199001  BG 1  2.689326e+06   8021.366300  060371990011
# 62      1394  2060101  206010  BG 1  1.209237e+07  19311.276607  060372060101
#
#    Geo_STATE Geo_COUNTY                                           geometry
# 32        06        037  POLYGON ((-118.24924 34.06524, -118.24930 34.0...
# 58        06        037  MULTIPOLYGON (((-118.19418 34.07321, -118.1941...
# 27        06        037  POLYGON ((-118.25366 34.07186, -118.25391 34.0...
# 34        06        037  POLYGON ((-118.21482 34.07929, -118.21565 34.0...
# 62        06        037  POLYGON ((-118.22954 34.07231, -118.22914 34.0...

# %%
#renaming FIPS to Geo_FIPS so I can merge the dataframes
age_renter.rename(columns = {'FIPS':'Geo_FIPS'}, inplace=True)
age_renter.sample(5)
# Out:
#          Geo_FIPS  SE_A01003B_001  SE_A01003B_002  SE_A01003B_003  \
# 1188  06037400603             690               9             156
# 2250  06037701000            1803               0             314
# 1016  06037273902            1145               0             288
# 750   06037221602             805              36             232
# 1703  06037533403             416              16              70
#
#       SE_A01003B_004  SE_A01003B_005  SE_A01003B_006  SE_A01003B_007  \
# 1188             168             110              51              50
# 2250             299             461             179             184
# 1016             420             182              38              52
# 750              186             157              49              32
# 1703              91              90              32               9
#
#       SE_A01003B_008  SE_A01003B_009  SE_A01003B_010
# 1188              87              59               0
# ...

# %%
tracts = geopandas.read_file('Census_Tracts_2020.geojson')
tracts.head()
# Out:
#    OBJECTID    CT20    LABEL   ShapeSTArea  ShapeSTLength  \
# 0         1  101110  1011.10  1.229562e+07   15083.854287
# 1         2  101122  1011.22  2.845774e+07   31671.455844
# 2         3  101220  1012.20  7.522093e+06   12698.783810
# 3         4  101221  1012.21  3.812000e+06    9161.710543
# 4         5  101222  1012.22  3.191371e+06    9980.600461
#
#                                             geometry
# 0  POLYGON ((-118.28491 34.25948, -118.28492 34.2...
# 1  POLYGON ((-118.29015 34.27417, -118.29015 34.2...
# 2  POLYGON ((-118.28100 34.25592, -118.28198 34.2...
# 3  POLYGON ((-118.28735 34.25591, -118.28863 34.2...
# 4  POLYGON ((-118.28594 34.25405, -118.28594 34.2...

# %%
# imported tracts from LA Times
tracts.plot(figsize=(12,10))
# Out:
# <AxesSubplot: >

# %%
chinatown_rentage = chinatown.merge(age_renter,on="Geo_FIPS")

# %%
# this didn't work, as there was no overlap in Geo_FIPS
chinatown_rentage.head()
# Out:
# Empty GeoDataFrame
# Columns: [OBJECTID, BG20, CT20, LABEL, ShapeSTAre, ShapeSTLen, Geo_FIPS, Geo_STATE, Geo_COUNTY, geometry, Renter-Occupied Housing Units, Renter 15 to 24 Years, Renter 25 to 34 Years, Renter 35 to 44 Years, Renter 45 to 54 Years, Renter 55 to 59 Years, Renter 60 to 64 Years, Renter 65 to 74 Years, Renter 75 to 84 Years, Renter 85 Years and Over]
# Index: []

# %%
# trying to cut out all unnecessary columns
tracts = tracts[['CT20','geometry']].copy()

# %%
tracts['Geo_FIPS'] ='06' + '037' + tracts['CT20']

# %%
tracts.head()
# Out:
#      CT20                                           geometry     Geo_FIPS
# 0  101110  POLYGON ((-118.28491 34.25948, -118.28492 34.2...  06037101110
# 1  101122  POLYGON ((-118.29015 34.27417, -118.29015 34.2...  06037101122
# 2  101220  POLYGON ((-118.28100 34.25592, -118.28198 34.2...  06037101220
# 3  101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...  06037101221
# 4  101222  POLYGON ((-118.28594 34.25405, -118.28594 34.2...  06037101222

# %%
tracts_rentage = tracts.merge(age_renter,on="Geo_FIPS")

# %%
# merging this time worked
tracts_rentage.head()
# Out:
#      CT20                                           geometry     Geo_FIPS  \
# 0  101110  POLYGON ((-118.28491 34.25948, -118.28492 34.2...  06037101110
# 1  101122  POLYGON ((-118.29015 34.27417, -118.29015 34.2...  06037101122
# 2  101220  POLYGON ((-118.28100 34.25592, -118.28198 34.2...  06037101220
# 3  101221  POLYGON ((-118.28735 34.25591, -118.28863 34.2...  06037101221
# 4  101222  POLYGON ((-118.28594 34.25405, -118.28594 34.2...  06037101222
#
#    Renter-Occupied Housing Units  Renter 15 to 24 Years  \
# 0                            644                     38
# 1                            344                     33
# 2                            762                      5
# 3                           1140                      0
# 4                            816                      0
#
#    Renter 25 to 34 Years  Renter 35 to 44 Years  Renter 45 to 54 Years  \
# 0                     73                     93                    124
# ...

# %%
# able to make a map!
tracts_rentage.plot(figsize=(12,10),
                 column='Renter 65 to 74 Years',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <AxesSubplot: >

# %%
print("blockgroups_agerent", tracts_rentage.crs)
# Out:
# blockgroups_agerent epsg:4326

# %%
# now going to try and clip only for neighborhoods chinatown, lincoln heights, elysian park, and echo park
neighborhoods = geopandas.read_file('LA_Times_Neighborhood_Boundaries.zip')

# %%
neighborhoods.plot(figsize=(12,10))
# Out:
# <AxesSubplot: >

# %%
neighborhoods.sample(5)
# Out:
#     OBJECTID                    name  \
# 4          5  Baldwin Hills/Crenshaw
# 48        49    Hollywood Hills West
# 38        39           Griffith Park
# 72        73          Pico-Robertson
# 77        78             Rancho Park
#
#                                              geometry
# 4   POLYGON ((-118.36102 34.02532, -118.36026 34.0...
# 48  POLYGON ((-118.36956 34.12922, -118.36952 34.1...
# 38  POLYGON ((-118.30019 34.15791, -118.29884 34.1...
# 72  POLYGON ((-118.37731 34.06095, -118.37728 34.0...
# 77  POLYGON ((-118.41484 34.03232, -118.41235 34.0...

# %%
relevant_neighborhoods = set(('Echo Park','Lincoln Heights','Chinatown','Elysian Park'))
clipped_neighborhoods = neighborhoods.loc[neighborhoods['name'].isin(relevant_neighborhoods)] 
clipped_neighborhoods.head()
# Out:
#     OBJECTID             name  \
# 20        21        Chinatown
# 26        27        Echo Park
# 28        29     Elysian Park
# 56        57  Lincoln Heights
#
#                                              geometry
# 20  POLYGON ((-118.22473 34.06758, -118.22703 34.0...
# 26  POLYGON ((-118.24487 34.09569, -118.24454 34.0...
# 28  POLYGON ((-118.24246 34.09391, -118.24057 34.0...
# 56  POLYGON ((-118.21218 34.08389, -118.21194 34.0...

# %%
tracts_rentage_clipped = geopandas.clip(tracts_rentage, clipped_neighborhoods)
# Out:
# /opt/conda/lib/python3.10/site-packages/geopandas/tools/clip.py:67: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   clipped.loc[

# %%
tracts_rentage_clipped.plot(figsize=(12,10))
# Out:
# <AxesSubplot: >

# %%
# now clipping original map to 4 neighborhood area only
import folium
tracts_rentage_clipped.plot(figsize=(12,10),
                 column='Renter 65 to 74 Years',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <AxesSubplot: >

# %%
tracts_rentage_clipped.plot(figsize=(12,10),
                 column='Renter 75 to 84 Years',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <AxesSubplot: >

# %%
# creating choropleth map with the data and clipped maps

lat = tracts_rentage_clipped.geometry.centroid.x.mean()
long = tracts_rentage_clipped.geometry.centroid.y.mean()
print(lat,long)
# Out:
# -118.23536765631414 34.07330213724232
# /tmp/ipykernel_66/3291723661.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   lat = tracts_rentage_clipped.geometry.centroid.x.mean()
# /tmp/ipykernel_66/3291723661.py:4: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   long = tracts_rentage_clipped.geometry.centroid.y.mean()

# %%
m = folium.Map(location=[long,lat], zoom_start=13,tiles='CartoDB positron')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
folium.Choropleth(
    geo_data = tracts_rentage_clipped,
    data = tracts_rentage_clipped,
    columns=['Geo_FIPS', 'Renter 65 to 74 Years'],
    key_on="feature.properties.Geo_FIPS",
    fill_color="BuPu",
    line_weight=0.1, 
    fill_opacity=0.8,
    line_opacity=0.2,
    legend_name="Renters 65 to 74 Years").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
